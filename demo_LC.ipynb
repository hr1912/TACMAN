# %%
import sys
from pathlib import Path

p_temp = str(Path('~/link/TACMAN').expanduser())
None if p_temp in sys.path else sys.path.append(p_temp)
del p_temp

# %%
from IPython.display import display

import TACMAN
from TACMAN.utils.general import np,pd,sc,plt,mpl
from TACMAN.utils.general import get_time_tag

# %% [markdown]
# # set p_homo
#
# set the `p_homo` as the storage path for the gene homology relationship file between species. We provided a few gene homologous files, which are stored under the path `TACMAN/homo`.

# %%
p_homo = Path('~/link/TACMAN/homo').expanduser()


def get_homo_path(
        sp_ref,
        sp_que,
        p_homo_info
):
    p_homo_info = Path(p_homo_info)
    df_info = pd.read_csv(p_homo_info)
    index_ = df_info.query("sp_ref == '{}' & sp_que == '{}'".format(sp_ref, sp_que)).index
    assert index_.size == 1, "[get {} path]can not get speicifed and unique path\nsp_ref\tsp_que\n{}\t{}".format(
        index_.size, sp_ref, sp_que)
    res = Path(df_info.loc[index_[0], 'path'])
    if not res.is_absolute():
        res = p_homo_info.parent.joinpath(res)
    assert res.exists(), "[not exists] {}".format(res)
    return res

get_homo_path('human','mouse',p_homo.joinpath('info.csv'))\
    .__str__()[36:] # Hide my path
# Out:
# 'TACMAN/homo/human_to_mouse.txt'

# %% [markdown]
# # run
#
# set parameters and run TACMAN.

# %%
para = dict(
    adata_ref = sc.read_h5ad(Path('data/LC_h_Imm').joinpath('counts.h5ad')),
    adata_que = sc.read_h5ad(Path('data/LC_m_Imm').joinpath('counts.h5ad')),
    sp_ref = 'human',
    sp_que = 'mouse',
    key_cell_type = 'cell_type',
    tissue = 'LC',
    aligned=False,
    p_output=Path('output'),
    tag_output=get_time_tag()
)
para['p_homo'] = get_homo_path(para['sp_ref'],para['sp_que'],p_homo.joinpath('info.csv'))

# Optional
para['tag_output'] = 'LChImm-map-LCmImm;aligned={}'.format(para['aligned'])
para['stages']=[100,100,100]
para['is_1v1']=False

TACMAN.run(**para)
# Out:
# [250108-112311][has finished] LC;human-corss-mouse;LChImm-map-LCmImm;aligned=False

# %% [markdown]
# # Reuslt
#
# ## load adata

# %%
p_output = Path('output','LC;human-corss-mouse;LChImm-map-LCmImm;aligned=False')

adata = TACMAN.tl.load_result_adata(p_output,load_X=False)
display(adata)
# Out:
# AnnData object with n_obs × n_vars = 43759 × 0
#     obs: 'UMAP1', 'UMAP2', 'cell_type', 'type', 'species', 'true_label', 'pre_label', 'max_prob', 'is_right', 'model_label'
#     uns: 'p_item', 'p_fig', 'parameters'
#     obsm: 'X_umap'

# %% [markdown]
# ## get accuracy and weighted_f1_socre

# %%
print(
    'weighted_f1_socre',
    TACMAN.get_weighted_f1_score(adata),
    'ACC',
    TACMAN.get_accuracy(adata),sep='\n'
)
# Out:
# weighted_f1_socre
# {'ref': 0.979116673173128, 'que': 0.9402651445415701}
# ACC
# {'ref': 0.9795705770009838, 'que': 0.9402238887077492}

# %% [markdown]
# ## plot

# %%
TACMAN.pl.cmap.COLOR_DF
# Out:
#             palette_type                                             colors  \
# name
# NPG                  nrc  #E64B35,#4DBBD5,#00A087,#3C5488,#F39B7F,#8491B...
# AAAS             default  #3B4992,#EE0000,#008B45,#631879,#008280,#BB002...
# NEJM             default  #BC3C29,#0072B5,#E18727,#20854E,#7876B1,#6F99A...
# Lancet            lanonc  #00468B,#ED0000,#42B540,#0099B4,#925E9F,#FDAF9...
# JAMA             default  #374E55,#DF8F44,#00A1D5,#B24745,#79AF97,#6A659...
# BMJ              default  #2A6EBB,#F0AB00,#C50084,#7D5CC6,#E37222,#69BE2...
# JCO              default  #0073C2,#EFC000,#868686,#CD534C,#7AA6DC,#003C6...
# UCSCGB           default  #FF0000,#FF9900,#FFCC00,#00FF00,#6699FF,#CC33F...
# D3            category20  #1F77B4,#FF7F0E,#2CA02C,#D62728,#9467BD,#8C564...
# Observable  observable10  #4269D0,#EFB118,#FF725C,#6CC5B0,#3CA951,#FF8AB...
# LocusZoom        default  #D43F3A,#EEA236,#5CB85C,#46B8DA,#357EBD,#9632B...
# IGV              default  #5050FF,#CE3D32,#749B58,#F0E685,#466983,#BA633...
#
#             length
# name
# NPG             10
# AAAS            10
# NEJM             8
# Lancet           9
# JAMA             7
# BMJ              9
# JCO             10
# UCSCGB          26
# D3              20
# Observable      10
# LocusZoom        7
# IGV             51

# %%
kw_scatter=dict(s=1)

# %%
plt.close('all')
fig,axs = TACMAN.pl.figure.subplots_get_fig_axs(
    nrows=1,ncols=2,ratio_ncols=3,ratio_nrows=3,
    rc=TACMAN.pl.rc_frame
)

cmap = TACMAN.pl.cmap.get('BMJ',['human','mouse'])

TACMAN.pl.umap(adata,'species',cmap=cmap,ax=axs[0],kw_scatter=kw_scatter)
axs[0].set_title('species')
TACMAN.pl.cmap.show(cmap,ax=axs[1],text_x=.03)

display(fig)
del cmap,axs,fig

# %%
plt.close('all')
fig,axs = TACMAN.pl.figure.subplots_get_fig_axs(
    nrows=1,ncols=4,ratio_ncols=3,ratio_nrows=3,
    rc=TACMAN.pl.rc_frame
)

cmap = TACMAN.pl.cmap.get('Observable',np.unique(adata.obs['true_label']))

ax = axs[0]
TACMAN.pl.umap(adata[adata.obs['type'] == 'ref'],
               'model_label',cmap=cmap,ax=ax,kw_scatter=kw_scatter)
ax.set_title('Human R')

ax = axs[1]
TACMAN.pl.umap(adata[adata.obs['type'] == 'que'],
               'model_label',cmap=cmap,ax=ax,kw_scatter=kw_scatter)
ax.set_title('Mouse Q')

ax = axs[2]
TACMAN.pl.umap(adata[adata.obs['type'] == 'que'],
               'true_label',cmap=cmap,ax=ax,kw_scatter=kw_scatter)
ax.set_title('Mouse O')

ax = axs[3]
TACMAN.pl.cmap.show(cmap,ax=ax,text_x=.03,fontdict=dict(fontsize=6))

display(fig)
del cmap,axs,fig

# %%
order_row = 'B cells,Basophils,MoMacDC,NK cells,Neutrophils,T cells,pDC'.split(',')
order_col = 'B cells,Mast cells,MoMacDC,NK cells,Neutrophils,T cells'.split(',')

plt.close('all')

ax=TACMAN.pl.max_prob(adata,dataset_type='que',factor_size=200,
                      order_col=order_col,order_row=order_row)
ax.set_xlabel('Mouse Q')
ax.set_ylabel('Mouse O')

ax.figure

# %%
plt.close('all')
cmap = mpl.colors.LinearSegmentedColormap.from_list("mycmap",
            '#237AFF,#FFFFFF,#FF5959'.split(','))
ax=TACMAN.pl.confusion_matrix(adata,dataset_type='que',
    order_col=order_col,order_row=order_row,cmap=cmap)
ax.set_xlabel('Mouse Q')
ax.set_ylabel('Mouse O')

ax.figure
