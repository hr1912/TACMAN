# %%
source("./script/map_seurat.r")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# [library] tidyverse
# Loading required package: SeuratObject
#
# Loading required package: sp
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
# [library] Seurat
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
# [library] Matrix
# Loading required package: Rcpp
# [library] harmony
# [library] IRdisplay
#
# > function----------------------------------------
# Seurat_to_mtx
#
# > Map_Seurat function-----------------------------
# Map_Seurat_normalize
# Map_Seurat_cluster
# Map_Seurat_mapquery
# precess_after_Seurat
# run_Seurat			[simply]
#
# > other-------------------------------------------
# get_path_varmap
# show_obj
# savefig
# Seurat_metadata_leftjoin
# Seurat_gene_detect

# %%
p_adata = "./data/mtx/HCL_Spleen"
adata = load_Seuratobj(p_adata)
adata = Map_Seurat_normalize(adata)
# Out:
# plot without title

# %%
nbatch = adata@meta.data %>%
  distinct(batch) %>%
  nrow()

# %%
key_batch = "batch"
key_celltype= "cell_type"
dims = 1:20
resolution = 0.1
if(nbatch > 1){
    adata = Map_Seurat_cluster_run_harmony(
        adata, dims, resolution, key_batch, key_celltype
    )
}else{
    adata = Map_Seurat_cluster(adata,dims,resolution,key_celltype)
}
# Out:
# Warning message:
# “The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session”
# plot without title

# %%
adata@meta.data %>% head
# Out:
#                                                cell_name
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1
#                                                orig.ident  nCount_RNA
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 AdultSpleen 3669
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 AdultSpleen 6279
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 AdultSpleen 2073
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 AdultSpleen 2264
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 AdultSpleen 4440
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 AdultSpleen 3296
#                                                nFeature_RNA source_cluster
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 1391         Adult-Spleen1_1
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 2122         Adult-Spleen1_1
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1  637         Adult-Spleen1_1
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1  690         Adult-Spleen1_1
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 1544         Adult-Spleen1_1
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1  895         Adult-Spleen1_1
#                                                source_cell_type
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 B cell (Plasmocyte)_IGHG_IGK high
#                                                batch         RNA_snn_res.0.1
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 Adult-Spleen1 1
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 Adult-Spleen1 1
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 Adult-Spleen1 1
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 Adult-Spleen1 1
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 Adult-Spleen1 1
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 Adult-Spleen1 1
#                                                seurat_clusters UMAP1
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1 1               5.887603
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1 1               4.619915
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 1               5.003140
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 1               5.195195
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1 1               4.904770
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 1               6.038453
#                                                UMAP2
# AdultSpleen_1.TGATCAGAATTATGAAGC|Adult-Spleen1  1.5855274
# AdultSpleen_1.TTCCGCCGAGTAATCTCT|Adult-Spleen1  1.3362400
# AdultSpleen_1.TGAAGCTCACTTTCAAAG|Adult-Spleen1 -0.7735709
# AdultSpleen_1.CCAGACAAAACGGCAGGA|Adult-Spleen1 -6.5477993
# AdultSpleen_1.CTCCATTCTACCAGGGTC|Adult-Spleen1  0.4523723
# AdultSpleen_1.CCGACGATGCTTATCAAC|Adult-Spleen1 -6.4684278

# %%
tbl_cell_type <- tribble(
  ~seurat_clusters,~cell_type,
    '0',"B cell",
    '1',"B cell",
    '2','T cell',
    '3','neutrophil',
    '4','endothelial cell',
    '5',"macrophage",
    '6','erythroid cell',
)
adata@meta.data <- adata@meta.data %>% 
    mutate(seurat_clusters = as.character(seurat_clusters)) %>%
    select(!any_of('cell_type')) %>%
    Seurat_metadata_leftjoin(tbl_cell_type,by = 'seurat_clusters')

nrow_ = 1
ncol_ = 2
set_repr_plot_szie(ncol_,nrow_)
p1 = UMAPPlot(adata,label =TRUE,label.size = 5,pt.size=1.5,
              group.by = 'seurat_clusters',raster=TRUE) + them_legend
p2 = UMAPPlot(adata,label =TRUE,label.size = 5,pt.size=1.5,
              group.by = 'cell_type',raster=TRUE) + them_legend
p_cluster = cowplot::plot_grid(p1,p2,nrow = nrow_,ncol = ncol_)
p_cluster %>% print
# Out:
# plot without title

# %%
p_marker = file.path(p_adata,"marker.tsv")
if(!file.exists(p_marker)){
    Idents(adata) <- "seurat_clusters"
    df_marker = FindAllMarkers(adata)
    df_marker %>%  write.table(p_marker,sep="\t")
}
df_marker = read.csv(p_marker,sep="\t",row.names = 1)
df_marker = df_marker %>% filter(
    p_val_adj < 0.05, avg_log2FC > 1, pct.1 > .4
) %>% arrange(cluster,desc(avg_log2FC))
df_marker %>% head(2)
# Out:
# Calculating cluster 1
#
# Calculating cluster 2
#
# Calculating cluster 0
#
# Calculating cluster 3
#
# Calculating cluster 6
#
# Calculating cluster 4
#
# Calculating cluster 5
#           p_val         avg_log2FC pct.1 pct.2 p_val_adj     cluster gene
# TSC22D3.2 1.611767e-195 1.469597   0.445 0.251 2.833808e-191 0       TSC22D3
# BTG2.2    8.456028e-148 1.379564   0.420 0.259 1.486739e-143 0       BTG2

# %%
ncol_ <- 2.2
nrow_ <- .6
set_repr_plot_szie(ncol_,nrow_)
temp_genes = c(
    str_split("CD3D,CD3E",",")[[1]],
    str_split("S100A8",",")[[1]],
    str_split("CSF1R",",")[[1]],
    str_split("HBA1",",")[[1]],
    str_split("PECAM1",",")[[1]],
    str_split("CD79A,SDC1",",")[[1]])
p = DotPlot(
    adata,
    temp_genes,group.by="cell_type"
)
p %>% print
# Out:
# plot without title

# %%
adata@meta.data %>% write.table(file.path(p_adata,"obs.tsv"),sep="\t")
